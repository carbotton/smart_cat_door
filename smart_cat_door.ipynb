# %% [markdown]
# <a href="https://colab.research.google.com/github/carbotton/smart_cat_door/blob/main/smart_cat_door.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Descarga de imagenes de Open Images con anotaciones para YOLO

# %% [markdown]
# **Seguir los pasos en:** https://github.com/carbotton/train-yolov8-custom-dataset-step-by-step-guide

# %% [markdown]
# # Entrenar modelo para reconocer gatos

# %%
# !pip install ultralytics  # YOLO
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 902.2/902.2 kB 56.0 MB/s eta 0:00:00
# ...

# %%
import os

from ultralytics import YOLO


# Load a model
model = YOLO("yolov8n.yaml")  # build a new model from scratch

# Use the model
results = model.train(data="/content/drive/MyDrive/Colab Notebooks/smart_cat_door/config_file.yaml", epochs=10)  # train the model
# Out:
# Ultralytics 8.3.53 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !scp -r /content/runs '/content/drive/MyDrive/Colab Notebooks/smart_cat_door/runs02_10epoch_gpu'
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-12-17522bc34eeb> in <cell line: 1>()
# ----> 1 get_ipython().system("scp -r /content/runs '/content/drive/MyDrive/Colab Notebooks/smart_cat_door/runs02_10epoch_gpu'")
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#      97       kwargs.update({'also_return_output': True})
#      98
# ---> 99     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#     100
#     101     if pip_warn:
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     452   # is expected to call this function, thus adding one level of nesting to the
#     453   # stack.
# --> 454   result = _run_command(
# ...

# %%
import shutil
import google.colab

# Copy the 'runs' directory to your Google Drive
google.colab.files.upload()  # This is required for some reason
shutil.copytree('/content/runs', '/content/drive/MyDrive/Colab Notebooks/smart_cat_door/runs', dirs_exist_ok=True)
# Out:
#      <input type="file" id="files-52759142-8a85-4c45-9999-853e2c03d37c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-52759142-8a85-4c45-9999-853e2c03d37c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # Predictions

# %%
import os

from ultralytics import YOLO
import cv2



video_path = "/content/IMG_5864.MP4"
video_path_out = '{}_out.mp4'.format(video_path)

cap = cv2.VideoCapture(video_path)
ret, frame = cap.read()
H, W, _ = frame.shape
out = cv2.VideoWriter(video_path_out, cv2.VideoWriter_fourcc(*'MP4V'), int(cap.get(cv2.CAP_PROP_FPS)), (W, H))

model_path = os.path.join('.', 'runs', 'detect', 'train2', 'weights', 'best.pt')

# Load a model
model = YOLO(model_path)  # load a custom model

threshold = 0.5

while ret:

    results = model(frame)[0]

    for result in results.boxes.data.tolist():
        x1, y1, x2, y2, score, class_id = result

        if score > threshold:
            cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 4)
            cv2.putText(frame, results.names[int(class_id)].upper(), (int(x1), int(y1 - 10)),
                        cv2.FONT_HERSHEY_SIMPLEX, 1.3, (0, 255, 0), 3, cv2.LINE_AA)

    out.write(frame)
    ret, frame = cap.read()

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# 0: 384x640 (no detections), 12.6ms
# Speed: 3.5ms preprocess, 12.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.0ms
# Speed: 7.2ms preprocess, 14.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 11.1ms
# Speed: 3.2ms preprocess, 11.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.0ms
# Speed: 4.3ms preprocess, 10.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.5ms
# Speed: 3.3ms preprocess, 10.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 9.8ms
# Speed: 3.8ms preprocess, 9.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.0ms
# ...

# %%
results = model.predict(source='/content/00febd00ede4b95c.jpg', save=True)  # Run predictions
# Out:
# image 1/1 /content/00febd00ede4b95c.jpg: 480x640 1 cat, 103.1ms
# Speed: 6.1ms preprocess, 103.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict
